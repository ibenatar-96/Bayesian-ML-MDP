# %% [markdown]
# <a href="https://colab.research.google.com/github/ibenatar-96/Bayesian-Modeling-RL/blob/main/bayesian_modeling_mdp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# !pip install numpyro
# !git clone https://github.com/ibenatar-96/Bayesian-Modelling-RL
# %cd /content/Bayesian-Modelling-RL
# !git pull
# %cd /content/
# Out:
# /content
# Collecting numpyro
#   Downloading numpyro-0.13.0-py3-none-any.whl (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.6/312.6 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: jax>=0.4.14 in /usr/local/lib/python3.10/dist-packages (from numpyro) (0.4.14)
# Requirement already satisfied: jaxlib>=0.4.14 in /usr/local/lib/python3.10/dist-packages (from numpyro) (0.4.14+cuda11.cudnn86)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from numpyro) (1.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from numpyro) (1.23.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from numpyro) (4.66.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.14->numpyro) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.14->numpyro) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.14->numpyro) (1.10.1)
# Installing collected packages: numpyro
# Successfully installed numpyro-0.13.0
# Cloning into 'Bayesian-Modelling-RL'...
# remote: Enumerating objects: 484, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 484 (delta 84), reused 78 (delta 35), pack-reused 335
# Receiving objects: 100% (484/484), 9.72 MiB | 22.42 MiB/s, done.
# Resolving deltas: 100% (283/283), done.
# /content/Bayesian-Modelling-RL
# Already up to date.
# /content

# %%
import numpy as np
import numpyro
import numpyro.distributions as dist
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import sys
import os
import time
sys.path.append('/content/Bayesian-Modelling-RL')
import actions
import environment
import utils
import solver
import actions
import loggers

numpyro.set_host_device_count(4)

# %%
utils.init_model_params()
model_parameters = utils.INIT_MODEL_PARAMETERS
observation_f = "observations.log"
open(observation_f, 'w').close()
slvr = solver.Solver(model_parameters, environment, observation_f, colab=True)
slvr.run()
# Out:
# Agent Q-Learning: 100%|██████████| 50/50 [00:01<00:00, 25.21it/s]
# Total Time: 0:00:01.993688
# Agent Playing REAL PARAMETERS Tic-Tac-Toe
#
# 	Testing 12 Tic-Tac-Toe Games
# Agent Playing Tic-Tac-Toe..: 100%|██████████| 12/12 [00:00<00:00, 90.77it/s]
# 	Total Games Won: 1/12
# 	Playing Real & Collecting Logs 15 Tic-Tac-Toe Games
# Playing Real Tic-Tac-Toe & Collecting Logs..: 100%|██████████| 15/15 [00:00<00:00, 96.91it/s]
# 	Total Games Won: 4/15

# %%
model_beta_parameters = {}
fn_numeric_mapping = {}
posterior_model_parameters = {}

# %% [markdown]
# # Parsing Observation file
# As defined in the description.
#
# Initialization:
# \
# $ \quad 1.\;fn\_numeric\_mapping = \{'ai\_mark':\;0\} $
# \
# $ \quad 2.\;model\_beta\_parameters = \{(0,1):\; \{\alpha:\;1,\;\beta:1\},\;(0,2):\;\{\alpha:\;1,\;\beta:1\},\;...,\; (0,9):\; \{\alpha:\;1,\;\beta:1\}\} $
#
# \
# Returns:
# \
# $\quad obs\;list = [(state,\;(function\;number, action\;parameter),\;next\;state),\;...]$

# %%
def parse_obs(obs_file):
    """
    Parses the Observation File, returns a List of tuples,
    where each tuple is composed of (State, (Function, Action Parameter), Next State)
    for example:
    State: [-1, 1, 0, -1, 0, -1, 1, 0, 0] where -1 indicates 'X' on the Board, 1 indicates 'O', and 0 indicates None (empty cell)
    (Function, Action Parameter): (0, 5) -> 0 is the number assigned for the function 'ai_mark', mapping is located in fn_numeric_mapping
    Next State: [-1, 1, 0, -1, 1, -1, 1, 0, 0].

    0 is mapped to 'ai_mark' function in global fn_numeric_mapping variable. This mapping exists because NumPyro
    MCMC expects numeric values when running inference.

    fn_numeric_mapping = {
        'ai_mark': 0,
        ...
    }

    This Function also adds initial 'alpha' and 'beta' parameters to the global model_beta_parameters for every NEW
    fn_action and action_param it encounters.
    for example - model_beta_parameters = {
    (0, 5): {'alpha': 1, 'beta': 1},
    (0, 1): {'alpha': 1, 'beta': 1} ... }
    """

    # Converts states from: [['X', 'O', None], ['X', None, 'X'], ['O', None, None]] to [-1, 1, 0, -1, 0, -1, 1, 0, 0]
    # Meaning, creating a minimal state representation, where 'X' is marked a -1, 'O' as 1, and None as 0.
    def minimal_state(state):
        minimal_repr = []
        for i in range(len(state)):
            for j in range(len(state[i])):
                if state[i][j] == 'X':
                    minimal_repr.append(-1)
                elif state[i][j] == 'O':
                    minimal_repr.append(1)
                else:
                    minimal_repr.append(0)
        return minimal_repr

    obs_list = []
    fn_numeric_count = 0
    global model_beta_parameters, fn_numeric_mapping
    with open(obs_file, "r") as obs_log:
        for episode in obs_log:
            if not episode.startswith("EPISODE:"):
                continue
            episode = episode.lstrip("EPISODE:").strip()  # Remove leading/trailing whitespaces and newlines
            episode_list = eval(episode)  # Convert the line string to a list
            for (state, (fn_name, action_param), next_state) in episode_list:
                if fn_name in utils.IGNORE_ACTIONS:
                    continue
                if fn_name in fn_numeric_mapping.keys():
                    fn_numeric = fn_numeric_mapping[fn_name]
                else:
                    fn_numeric = fn_numeric_count
                    fn_numeric_mapping[fn_name] = fn_numeric_count
                    fn_numeric_count += 1
                obs_list.append((minimal_state(state), (fn_numeric, action_param), minimal_state(next_state)))
                if not (fn_numeric, action_param) in model_beta_parameters:
                    model_beta_parameters[(fn_numeric, action_param)] = {'alpha': 1, 'beta': 1}
    model_beta_parameters = dict(sorted(model_beta_parameters.items()))
    return obs_list

# %%
obs_list = parse_obs(utils.LOG_FILE)

# %% [markdown]
# # AI Model
# $ p_i \sim Beta(\alpha_i, \beta_i)\;\;\;1 \le i \le number\;of\;functions\;and\;action\;parameters $
#
# $ o_i \sim Bernoulli(p_i)\;\;\;1 \le i \le number\;of\;observations $

# %%
def ai_model(obs=None):
    """
    (Tic-Tac-Toe) AI Agent model with NumPyro.
    p is a dictionary mapping (function, action parameter) -> sample from Beta distribution using (alpha, beta).
    obs = [
    ([-1,1,0,...], (0,3), [-1,1,1,...]),
    ([-1,1,...,0], (0,9), [-1,1,...,1]),
    ]
    """
    # p ~ Beta(alpha, beta)
    p = {}
    n_obs = len(model_beta_parameters.keys())

    for key in model_beta_parameters.keys():
        alpha = model_beta_parameters[key]['alpha']
        beta = model_beta_parameters[key]['beta']
        p[key] = numpyro.sample(f"p{str(key)}", dist.Beta(alpha, beta))# p = {(0,1): sample_1, (0,2): sample_2, ..., (0,9): sample_9}

    if obs is not None:
        # p_actions = jax.numpy.array([p[action] for _, action, _ in obs]) # [sample_4, sample_5, sample_2, sample_7, sample_4, sample_5, ...]
        # success = jax.numpy.array([1 if state != next_state else 0 for state, _, next_state in obs]) # [1, 0, 1, 1, ...]
        success = []
        for i, key in enumerate(model_beta_parameters.keys()):
            success.append(jnp.array([1 if state != next_state else 0 for state, action, next_state in obs if key == action]))
        max_length = max(len(row) for row in success)
        padded_data = [jnp.concatenate((row, jnp.array([None] * (max_length - len(row))))) for row in success]
        success = jnp.array(padded_data)
    else:
        success = None


    with numpyro.plate("obs", size=n_obs):
        numpyro.sample("o", dist.Bernoulli(p), obs=success)

# %%
numpyro.render_model(ai_model, model_args=(obs_list,))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py in broadcast_shapes(*shapes)
#     147   try:
# --> 148     return _broadcast_shapes_cached(*shapes)
#     149   except:
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     262       else:
# --> 263         return cached(config._trace_context(), *args, **kwargs)
#     264
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     255     def cached(_, *args, **kwargs):
# --> 256       return f(*args, **kwargs)
#     257
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_cached(*shapes)
#     153 def _broadcast_shapes_cached(*shapes: tuple[int, ...]) -> tuple[int, ...]:
# --> 154   return _broadcast_shapes_uncached(*shapes)
#     155
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     169   if result_shape is None:
# --> 170     raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}")
#     171   return result_shape
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(9,), (9, 7)]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-7cb88c4156bc> in <cell line: 1>()
# ----> 1 numpyro.render_model(ai_model, model_args=(obs_list,))
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/inspect.py in render_model(model, model_args, model_kwargs, filename, render_distributions, render_params)
#     621     :param bool render_params: Whether to show params in the plot.
#     622     """
# --> 623     relations = get_model_relations(
#     624         model,
#     625         model_args=model_args,
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/inspect.py in get_model_relations(model, model_args, model_kwargs)
#     394     }
#     395
# --> 396     sample_params_deps = eval_provenance(get_log_probs, **samples, **params)
#     397
#     398     sample_sample = {}
#
# /usr/local/lib/python3.10/dist-packages/numpyro/ops/provenance.py in eval_provenance(fn, **kwargs)
#      41     # for simplicity. In principle, they can be merged so that we only need to walk
#      42     # through the equations once.
# ---> 43     jaxpr, avals_out, _ = trace_to_jaxpr_dynamic(
#      44         lu.wrap_init(wrapped_fun.call_wrapped, {}), avals
#      45     )
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     312   def wrapper(*args, **kwargs):
#     313     with TraceAnnotation(name, **decorator_kwargs):
# --> 314       return func(*args, **kwargs)
#     315     return wrapper
#     316   return wrapper
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/partial_eval.py in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2153   with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2154     main.jaxpr_stack = ()  # type: ignore
# -> 2155     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2156       fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2157     del main, fun
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2175     in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2176     in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2177     ans = fun.call_wrapped(*in_tracers_)
#    2178     out_tracers = map(trace.full_raise, ans)
#    2179     jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/linear_util.py in call_wrapped(self, *args, **kwargs)
#     186
#     187     try:
# --> 188       ans = self.f(*args, **dict(self.params, **kwargs))
#     189     except:
#     190       # Some transformations yield from inside context managers, so we have to
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/inspect.py in get_log_probs(**sample)
#     378         for name, site in tr.items():
#     379             if site["type"] == "sample":
# --> 380                 provenance_arrays[name] = site["fn"].log_prob(site["value"])
#     381             elif site["type"] == "deterministic":
#     382                 provenance_arrays[name] = site["args"][0]
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in log_prob(self, value, intermediates)
#     645     def log_prob(self, value, intermediates=None):
#     646         # TODO: utilize `intermediates`
# --> 647         shape = lax.broadcast_shapes(
#     648             self.batch_shape,
#     649             jnp.shape(value)[: max(jnp.ndim(value) - self.event_dim, 0)],
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py in broadcast_shapes(*shapes)
#     148     return _broadcast_shapes_cached(*shapes)
#     149   except:
# --> 150     return _broadcast_shapes_uncached(*shapes)
#     151
#     152 @cache()
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/lax.py in _broadcast_shapes_uncached(*shapes)
#     168   result_shape = _try_broadcast_shapes(shape_list)
#     169   if result_shape is None:
# --> 170     raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}")
#     171   return result_shape
#     172
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(9,), (9, 7)]

# %%
"""
Evaluates Prior Predictive from the Prior Dist.
Expecting to see mass in the bar where observation and imaginations are aligned.
"""
prior_predi = numpyro.infer.Predictive(ai_model, num_samples=10000)
prior_samples = prior_predi(jax.random.PRNGKey(int(time.time() * 1E6)))

num_mapping = len(model_beta_parameters.keys())
num_rows, num_cols = utils.largest_divisors(num_mapping)
assert num_rows * num_cols == num_mapping
fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 12))
plt.subplots_adjust(hspace=0.5)
plt.title("prior predictive")
for i in range(num_rows):
    for j in range(num_cols):
        fn_num, action_param = list(model_beta_parameters.keys())[i*3 + j]
        # o_key = f"p{str((fn_num, action_param))}" # Need to revert this to o{str(key)}
        x_titles = ["Fail", "Success"]
        fn_name = next((k for k, v in fn_numeric_mapping.items() if v == fn_num), None)
        title = (fn_name, action_param)
        axs[i, j].set_title(title)
        axs[i, j].set_xlim(0, 1)
        success_counts = np.sum(prior_samples['o'][i*3 + j] > 0.5, axis=0)
        fail_counts = np.sum(prior_samples['o'][i*3 + j] < 0.5, axis=0)
        normalized_vector = [np.mean(fail_counts), np.mean(success_counts)]
        sum_normalized = np.sum(normalized_vector)
        normalized_vector /= sum_normalized
        axs[i, j].bar(x_titles, normalized_vector)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in _len(self, ignored_tracer)
#    1596     try:
# -> 1597       return self.shape[0]
#    1598     except IndexError as err:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in result_type(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_internal.py in _usefields(adict, align)
#      61     if names is None:
# ---> 62         names, formats, offsets, titles = _makenames_list(adict, align)
#      63     else:
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_internal.py in _makenames_list(adict, align)
#      29     for fname, obj in adict.items():
# ---> 30         n = len(obj)
#      31         if not isinstance(obj, tuple) or n not in (2, 3):
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in __len__(self)
#     641   def __len__(self):
# --> 642     return self.aval._len(self)
#     643
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in _len(self, ignored_tracer)
#    1598     except IndexError as err:
# -> 1599       raise TypeError("len() of unsized object") from err  # same as numpy error
#    1600
#
# TypeError: len() of unsized object
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-59c4811c5c6a> in <cell line: 6>()
#       4 """
#       5 prior_predi = numpyro.infer.Predictive(ai_model, num_samples=10000)
# ----> 6 prior_samples = prior_predi(jax.random.PRNGKey(int(time.time() * 1E6)))
#       7
#       8 num_mapping = len(model_beta_parameters.keys())
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/util.py in __call__(self, rng_key, *args, **kwargs)
#    1007         """
#    1008         if self.batch_ndims == 0 or self.params == {} or self.guide is None:
# -> 1009             return self._call_with_params(rng_key, self.params, args, kwargs)
#    1010         elif self.batch_ndims == 1:  # batch over parameters
#    1011             batch_size = jnp.shape(tree_flatten(self.params)[0][0])[0]
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/util.py in _call_with_params(self, rng_key, params, args, kwargs)
#     984             )
#     985         model = substitute(self.model, self.params)
# --> 986         return _predictive(
#     987             rng_key,
#     988             model,
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/util.py in _predictive(rng_key, model, posterior_samples, batch_shape, return_sites, infer_discrete, parallel, model_args, model_kwargs)
#     821     rng_key = rng_key.reshape((*batch_shape, 2))
#     822     chunk_size = num_samples if parallel else 1
# --> 823     return soft_vmap(
#     824         single_prediction, (rng_key, posterior_samples), len(batch_shape), chunk_size
#     825     )
#
# /usr/local/lib/python3.10/dist-packages/numpyro/util.py in soft_vmap(fn, xs, batch_ndims, chunk_size)
#     408         fn = vmap(fn)
#     409
# --> 410     ys = lax.map(fn, xs) if num_chunks > 1 else fn(xs)
#     411     map_ndims = int(num_chunks > 1) + int(chunk_size > 1)
#     412     ys = tree_map(
#
#     [... skipping hidden 12 frame]
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/util.py in single_prediction(val)
#     795             )
#     796         else:
# --> 797             model_trace = trace(
#     798                 seed(substitute(masked_model, samples), rng_key)
#     799             ).get_trace(*model_args, **model_kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     169         :return: `OrderedDict` containing the execution trace.
#     170         """
# --> 171         self(*args, **kwargs)
#     172         return self.trace
#     173
#
# /usr/local/lib/python3.10/dist-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#     103             return self
#     104         with self:
# --> 105             return self.fn(*args, **kwargs)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#     103             return self
#     104         with self:
# --> 105             return self.fn(*args, **kwargs)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#     103             return self
#     104         with self:
# --> 105             return self.fn(*args, **kwargs)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#     103             return self
#     104         with self:
# --> 105             return self.fn(*args, **kwargs)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#     103             return self
#     104         with self:
# --> 105             return self.fn(*args, **kwargs)
#     106
#     107
#
# <ipython-input-80-add884cf9c5a> in ai_model(obs)
#      31
#      32     with numpyro.plate("obs", size=n_obs):
# ---> 33         numpyro.sample("o", dist.Bernoulli(p), obs=success)
#
# /usr/local/lib/python3.10/dist-packages/numpyro/primitives.py in sample(name, fn, obs, rng_key, sample_shape, infer, obs_mask)
#     220
#     221     # ...and use apply_stack to send it to the Messengers
# --> 222     msg = apply_stack(initial_msg)
#     223     return msg["value"]
#     224
#
# /usr/local/lib/python3.10/dist-packages/numpyro/primitives.py in apply_stack(msg)
#      51             break
#      52
# ---> 53     default_process_message(msg)
#      54
#      55     # A Messenger that sets msg["stop"] == True also prevents application
#
# /usr/local/lib/python3.10/dist-packages/numpyro/primitives.py in default_process_message(msg)
#      22     if msg["value"] is None:
#      23         if msg["type"] == "sample":
# ---> 24             msg["value"], msg["intermediates"] = msg["fn"](
#      25                 *msg["args"], sample_intermediates=True, **msg["kwargs"]
#      26             )
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in __call__(self, *args, **kwargs)
#     360         sample_intermediates = kwargs.pop("sample_intermediates", False)
#     361         if sample_intermediates:
# --> 362             return self.sample_with_intermediates(key, *args, **kwargs)
#     363         return self.sample(key, *args, **kwargs)
#     364
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in sample_with_intermediates(self, key, sample_shape)
#     318         :rtype: numpy.ndarray
#     319         """
# --> 320         return self.sample(key, sample_shape=sample_shape), []
#     321
#     322     def log_prob(self, value):
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in sample(self, key, sample_shape)
#     884
#     885     def sample(self, key, sample_shape=()):
# --> 886         return self.base_dist(rng_key=key, sample_shape=sample_shape)
#     887
#     888     def log_prob(self, value):
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in __call__(self, *args, **kwargs)
#     361         if sample_intermediates:
#     362             return self.sample_with_intermediates(key, *args, **kwargs)
# --> 363         return self.sample(key, *args, **kwargs)
#     364
#     365     def to_event(self, reinterpreted_batch_ndims=None):
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in sample(self, key, sample_shape)
#     641
#     642     def sample(self, key, sample_shape=()):
# --> 643         return self.sample_with_intermediates(key, sample_shape)[0]
#     644
#     645     def log_prob(self, value, intermediates=None):
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in sample_with_intermediates(self, key, sample_shape)
#     638
#     639     def sample_with_intermediates(self, key, sample_shape=()):
# --> 640         return self._sample(self.base_dist.sample_with_intermediates, key, sample_shape)
#     641
#     642     def sample(self, key, sample_shape=()):
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in _sample(self, sample_fn, key, sample_shape)
#     597         batch_shape = expanded_sizes + interstitial_sizes
#     598         # shape = sample_shape + expanded_sizes + interstitial_sizes + base_dist.shape()
# --> 599         samples, intermediates = sample_fn(key, sample_shape=sample_shape + batch_shape)
#     600
#     601         interstitial_dims = tuple(self._interstitial_sizes.keys())
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/distribution.py in sample_with_intermediates(self, key, sample_shape)
#     318         :rtype: numpy.ndarray
#     319         """
# --> 320         return self.sample(key, sample_shape=sample_shape), []
#     321
#     322     def log_prob(self, value):
#
# /usr/local/lib/python3.10/dist-packages/numpyro/distributions/discrete.py in sample(self, key, sample_shape)
#      82     def sample(self, key, sample_shape=()):
#      83         assert is_prng_key(key)
# ---> 84         samples = random.bernoulli(
#      85             key, self.probs, shape=sample_shape + self.batch_shape
#      86         )
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/random.py in bernoulli(key, p, shape)
#     843   """
#     844   key, _ = _check_prng_key(key)
# --> 845   dtype = dtypes.canonicalize_dtype(lax.dtype(p))
#     846   if shape is not None:
#     847     shape = core.as_named_shape(shape)
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/dtypes.py in dtype(x, canonicalize)
#     582       dt = np.result_type(x)
#     583     except TypeError as err:
# --> 584       raise TypeError(f"Cannot determine dtype of {x}") from err
#     585   if dt not in _jax_dtype_set and not issubdtype(dt, extended):
#     586     raise TypeError(f"Value '{x}' with dtype {dt} is not a valid JAX array "
#
# TypeError: Cannot determine dtype of {(0, 1): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>, (0, 2): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>, (0, 3): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>, (0, 4): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>, (0, 5): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>, (0, 6): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>, (0, 7): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>, (0, 8): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>, (0, 9): Traced<ShapedArray(float32[])>with<DynamicJaxprTrace(level=1/0)>}

# %%
"""
Runs Inference using MCMC.
"""
nuts_kernel = numpyro.infer.NUTS(ai_model)
mcmc = numpyro.infer.MCMC(
    nuts_kernel,
    num_warmup=500,
    num_chains=4,
    num_samples=5000)
mcmc.run(jax.random.PRNGKey(int(time.time() * 1E6)), obs=obs_list)
mcmc.print_summary()
# Out:
#   0%|          | 0/5500 [00:00<?, ?it/s]
#   0%|          | 0/5500 [00:00<?, ?it/s]
#   0%|          | 0/5500 [00:00<?, ?it/s]
#   0%|          | 0/5500 [00:00<?, ?it/s]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#    p(0, 1)      0.89      0.10      0.92      0.75      1.00  31035.88      1.00
#    p(0, 2)      0.89      0.10      0.92      0.75      1.00  31544.76      1.00
#    p(0, 3)      0.86      0.12      0.89      0.68      1.00  30883.70      1.00
#    p(0, 4)      0.83      0.14      0.87      0.63      1.00  31382.83      1.00
#    p(0, 5)      0.43      0.17      0.42      0.14      0.70  31755.91      1.00
#    p(0, 6)      0.83      0.14      0.87      0.63      1.00  29378.88      1.00
#    p(0, 7)      0.88      0.11      0.91      0.72      1.00  34469.01      1.00
#    p(0, 8)      0.86      0.12      0.89      0.68      1.00  28321.87      1.00
#    p(0, 9)      0.89      0.10      0.92      0.75      1.00  31406.32      1.00
#
# Number of divergences: 0

# %%
num_mapping = len(model_beta_parameters.keys())
num_rows, num_cols = utils.largest_divisors(num_mapping)
assert num_rows * num_cols == num_mapping
fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 12))
plt.subplots_adjust(hspace=0.5)
plt.title("posterior")
for i in range(num_rows):
    for j in range(num_cols):
        fn_num, action_param = list(model_beta_parameters.keys())[i*3 + j]
        p_key = f"p{str((fn_num, action_param))}"
        x_titles = ["Fail", "Success"]
        fn_name = next((k for k, v in fn_numeric_mapping.items() if v == fn_num), None)
        title = (fn_name, action_param)
        axs[i, j].set_title(title)
        axs[i, j].set_xlim(0, 1)
        success_counts = np.sum(mcmc.get_samples()[p_key] > 0.5, axis=0)
        fail_counts = np.sum(mcmc.get_samples()[p_key] < 0.5, axis=0)
        normalized_vector = [np.mean(fail_counts), np.mean(success_counts)]
        sum_normalized = np.sum(normalized_vector)
        normalized_vector /= sum_normalized
        axs[i, j].bar(x_titles, normalized_vector)

        # p_key = f"p{str(key)}"
        # axs[i, j].set_title(p_key)
        # axs[i, j].set_xlabel("p")
        # axs[i, j].hist(mcmc.get_samples()[p_key], density=True, bins='auto')
plt.show()

# %%
"""
Summarizes Posterior, displays attributes such as mean, standard deviation, quantiles.
"""
distribution_stats = {}
num_mapping = len(model_beta_parameters.keys())
num_rows, num_cols = utils.largest_divisors(num_mapping)
assert num_rows * num_cols == num_mapping
fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 12))
plt.subplots_adjust(hspace=0.5)
# obs_list = list(obs.items())
for i in range(num_rows):
    for j in range(num_cols):
        fn_num, action_param = list(model_beta_parameters.keys())[i*3 + j]
        fn_name = next((k for k, v in fn_numeric_mapping.items() if v == fn_num), None)
        title = (fn_name, action_param)
        key = (fn_num, action_param)
        real_param = utils.REAL_MODEL_PARAMETERS[(fn_name, action_param)]
        p_key = f"p{str(key)}"
        p = mcmc.get_samples()[p_key]
        p_mean = p.mean()
        p_stddev = p.std()
        distribution_stats[key] = {'mean': p_mean, 'stddev': p_stddev}
        quantiles = [0, 0.025, 0.25, 0.5, 0.75, 0.975, 1]
        pq = np.quantile(p, quantiles)
        print(f"stat\t{p_key}\n-------------")
        print(f"mean\t{p_mean:.3f}")
        print(f"stddev\t{p_stddev:.3f}")
        for q in range(len(quantiles)):
            print(f"{quantiles[q] * 100:3.0f}%\t{pq[q]:.3f}")
        print("\n")
        height, _, _ = axs[i, j].hist(p, histtype="step", lw=2, bins="auto", label="posterior")
        axs[i, j].set_title(f"p{title}")
        axs[i, j].axvline(real_param, ls="dashed", color="green", label="real prob")
        axs[i, j].axvline(p_mean, ls="dashed", color="red", label="mean")
        axs[i, j].fill_betweenx([0, height.max()], pq[1], pq[-2],
                                color="red", alpha=0.1, label=f"{(quantiles[-2] - quantiles[1]) * 100:.0f}%")
        axs[i, j].fill_betweenx([0, height.max()], pq[2], pq[-3],
                                color="red", alpha=0.2, label=f"{(quantiles[-3] - quantiles[2]) * 100:.0f}%")
        axs[i, j].legend()
plt.show()
# Out:
# stat	p(0, 1)
# -------------
# mean	0.888
# stddev	0.100
#   0%	0.302
#   2%	0.627
#  25%	0.839
#  50%	0.917
#  75%	0.965
#  98%	0.997
# 100%	1.000
#
#
# stat	p(0, 2)
# -------------
# mean	0.890
# stddev	0.098
#   0%	0.316
#   2%	0.633
#  25%	0.842
#  50%	0.917
#  75%	0.964
#  98%	0.997
# 100%	1.000
#
#
# stat	p(0, 3)
# -------------
# mean	0.857
# stddev	0.123
#   0%	0.138
#   2%	0.546
#  25%	0.794
#  50%	0.892
#  75%	0.953
#  98%	0.995
# 100%	1.000
#
#
# stat	p(0, 4)
# -------------
# mean	0.833
# stddev	0.139
#   0%	0.144
#   2%	0.484
#  25%	0.758
#  50%	0.869
#  75%	0.942
#  98%	0.994
# 100%	1.000
#
#
# stat	p(0, 5)
# -------------
# mean	0.429
# stddev	0.174
#   0%	0.021
#   2%	0.125
#  25%	0.299
#  50%	0.422
#  75%	0.554
#  98%	0.774
# 100%	0.962
#
#
# stat	p(0, 6)
# -------------
# mean	0.833
# stddev	0.143
#   0%	0.137
#   2%	0.475
#  25%	0.757
#  50%	0.873
#  75%	0.945
#  98%	0.995
# 100%	1.000
#
#
# stat	p(0, 7)
# -------------
# mean	0.875
# stddev	0.111
#   0%	0.205
#   2%	0.589
#  25%	0.821
#  50%	0.907
#  75%	0.961
#  98%	0.997
# 100%	1.000
#
#
# stat	p(0, 8)
# -------------
# mean	0.857
# stddev	0.123
#   0%	0.195
#   2%	0.536
#  25%	0.793
#  50%	0.890
#  75%	0.952
#  98%	0.996
# 100%	1.000
#
#
# stat	p(0, 9)
# -------------
# mean	0.889
# stddev	0.100
#   0%	0.245
#   2%	0.625
#  25%	0.841
#  50%	0.917
#  75%	0.966
#  98%	0.997
# 100%	1.000
